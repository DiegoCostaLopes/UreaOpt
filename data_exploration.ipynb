# %%
import pandas as pd

# %%
location_db = pd.read_pickle('data/processed/location_db.p')
results_biomass = pd.read_pickle('data/results/biomass_sold.p')
results_urea = pd.read_pickle('data/results/urea_sold.p')
results_route = pd.read_pickle('data/results/biomass_used.p')

# %%
location_db
# Out:
#                         name         state location_type  \
# id
# 5200050      Abadia de Goias         Goias          city
# 3100104  Abadia dos Dourados  Minas Gerais          city
# 5200100            Abadiania         Goias          city
# 1500107           Abaetetuba          Para          city
# 3100203               Abaete  Minas Gerais          city
# ...                      ...           ...           ...
# 4101150               Angulo        Parana          city
# 2900504        Erico Cardoso         Bahia          city
# 15001                 Obidos          Para   microregion
# 1505106               Obidos          Para          city
# 3533809                 Oleo     Sao Paulo          city
#
#          area_harvested_cocoa  cocoa  area_planted_cocoa  \
# id
# 5200050                     0      0                   0
# 3100104                     0      0                   0
# 5200100                     0      0                   0
# ...

# %%
results_biomass.columns = location_db.loc[results_biomass.columns, 'name']
results_urea.index = location_db.loc[results_urea.index, 'name']

# %%
results_biomass.loc[:, (results_biomass != 0).any()]
# Out:
# name               Barrinha  Guariba  Jaboticabal  Monte Alto    Pradopolis  \
# rice_husk               0.0      0.0          0.0         0.0      0.000000
# coffee_husk             0.0      0.0          0.0         0.0      0.000000
# corn_stover             0.0      0.0          0.0         0.0      0.000000
# soy_straw               0.0      0.0          0.0         0.0      0.000000
# sugarcane_straw         0.0      0.0          0.0         0.0      0.000000
# sugarcane_bagasse   49087.5  99110.0     284872.5     43477.5  32181.950617
#
# name                Taiacu   Taiuva  Taquaral  Taquaritinga
# rice_husk              0.0      0.0       0.0           0.0
# coffee_husk            0.0      0.0       0.0           0.0
# corn_stover            0.0      0.0       0.0           0.0
# soy_straw              0.0      0.0       0.0           0.0
# sugarcane_straw        0.0      0.0       0.0           0.0
# sugarcane_bagasse  34127.5  35997.5    9680.0      128749.5
